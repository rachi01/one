# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\rachi\\PycharmProjects\\one\\package1\\src'

# %%
os.chdir('C:\\Users\\rachi\\PycharmProjects\\one\\package1')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rachi\\PycharmProjects\\one\\package1'

# %%
os.chdir('C:\\Users\\rachi\\PycharmProjects\\one\\package1\\src')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rachi\\PycharmProjects\\one\\package1\\src'

# %%
os.makedirs('C:\\Users\\rachi\\PycharmProjects\\too')

# %%
os.chdir('C:\\Users\\rachi\\PycharmProjects\\too')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rachi\\PycharmProjects\\too'

# %%
os.chdir('C:\\Users\\rachi\\PycharmProjects\\one\\package1\\src')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rachi\\PycharmProjects\\one\\package1\\src'

# %%
os.path.abspath('python.exe')
# Out:
# 'C:\\Users\\rachi\\PycharmProjects\\one\\package1\\src\\python.exe'

# %%
os.listdir('.')
# Out:
# ['last_day.py', 'main.py', 'note1.ipynb', '__init__.py', '__pycache__']

# %%
os.path.exists('C:\\Users\\rachi\\PycharmProjects\\too')
# Out:
# True

# %%
os.path.isfile('python.exe')
# Out:
# False

# %%
os.path.isdir('.')
# Out:
# True

# %%
file = open('C:\\Users\\rachi\\PycharmProjects\\one\\package1\\src\\main.txt')

# %%
file.read()
# Out:
# 'from package1.src.last_day import get_last_day_datetime\n\n\ndef main():\n    a = 10 / 1\n    print(a)\n    print("hello world")\n    dd = get_last_day_datetime(datetime.datetime.now(), \'thursday\')\n\n    print(datetime.datetime.now())\n    print(dd)\n\nif __name__ == \'__main__\':\n    main()\n'

# %%
file.close()

# %%
file.readlines()
# Out:
# ['from package1.src.last_day import get_last_day_datetime\n',
#  '\n',
#  '\n',
#  'def main():\n',
#  '    a = 10 / 1\n',
#  '    print(a)\n',
#  '    print("hello world")\n',
#  "    dd = get_last_day_datetime(datetime.datetime.now(), 'thursday')\n",
#  '\n',
#  '    print(datetime.datetime.now())\n',
#  '    print(dd)\n',
#  '\n',
#  "if __name__ == '__main__':\n",
#  '    main()\n']

# %%
file2=open('C:\\Users\\rachi\\PycharmProjects\\one\\package1\\src\\main1.txt','w')

# %%
file2.write('hi')
# Out:
# 2

# %%
file2.close()

# %%
file3=open('C:\\Users\\rachi\\PycharmProjects\\one\\package1\\src\\main1.txt','r')

# %%
file3.read()
# Out:
# 'hi'

# %%
import shutil

# %%
os.chdir('C:\\Users\\rachi\\PycharmProjects\\one\\package1\\src')

# %%
shutil.copy('main1.txt', 'main2.txt')
# Out:
# 'main2.txt'

# %%
shutil.move('main2.txt', '..')
# Out:
# '..\\main2.txt'

# %%
import openpyxl

# %%
wb=openpyxl.load_workbook('Exemple_Hypermarché.xlsx')

# %%
sheets= wb.get_sheet_names()
# Out:
# C:\Windows\Temp\ipykernel_1324\3466170040.py:1: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   sheets= wb.get_sheet_names()

# %%
type(sheets)
# Out:
# list

# %%
sheets[1]
# Out:
# 'Retours'

# %%
sheets[0]
# Out:
# 'Achats'

# %%
wb.active
# Out:
# <Worksheet "Achats">

# %%
sheets
# Out:
# ['Achats', 'Retours', 'Personnes']

# %%
achatssheets=wb.get_sheet_by_name('Achats')
# Out:
# C:\Windows\Temp\ipykernel_1324\72336316.py:1: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   achatssheets=wb.get_sheet_by_name('Achats')

# %%
Retourssheets=wb.get_sheet_by_name('Retours')
# Out:
# C:\Windows\Temp\ipykernel_1324\1651200531.py:1: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   Retourssheets=wb.get_sheet_by_name('Retours')

# %%
Personnessheets=wb.get_sheet_by_name('Personnes')
# Out:
# C:\Windows\Temp\ipykernel_1324\2997882050.py:1: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   Personnessheets=wb.get_sheet_by_name('Personnes')

# %%
newsheets=wb.create_sheet('new')

# %%
wb.save('Exemple_Hypermarché.xlsx')

# %%
wb.remove_sheet(newsheets)
# Out:
# C:\Windows\Temp\ipykernel_1324\2327596027.py:1: DeprecationWarning: Call to deprecated function remove_sheet (Use wb.remove(worksheet) or del wb[sheetname]).
#   wb.remove_sheet(newsheets)

# %%
wb.save('Exemple_Hypermarché.xlsx')

# %%
achatssheets.dimensions
# Out:
# 'A1:T10001'

# %%
achatssheets.encoding
# Out:
# 'utf-8'

# %%
achatssheets.max_column
# Out:
# 20

# %%
achatssheets.max_row
# Out:
# 10001

# %%
achatssheets['H12'].value
# Out:
# 'Grand public'

# %%
for row in achatssheets.rows:
    print(row[0].value,row[1].value,row[2].value)
# Out:
# ID ligne ID commande Date de commande
# 1 ES-2014-1311038 2014-02-07 00:00:00
# 2 ES-2014-1311038 2014-02-07 00:00:00
# 3 ES-2014-1311038 2014-02-07 00:00:00
# 4 ES-2014-1311038 2014-02-07 00:00:00
# 5 ES-2014-1311038 2014-02-07 00:00:00
# 6 ES-2014-1311038 2014-02-07 00:00:00
# 7 ES-2014-1311038 2014-02-07 00:00:00
# 8 ES-2012-5113958 2012-08-01 00:00:00
# 9 ES-2012-5113958 2012-08-01 00:00:00
# 10 ES-2012-5113958 2012-08-01 00:00:00
# 11 ES-2012-2510515 2012-06-19 00:00:00
# 12 ES-2012-2510515 2012-06-19 00:00:00
# 13 ES-2012-2510515 2012-06-19 00:00:00
# 14 ES-2012-2510515 2012-06-19 00:00:00
# 15 ES-2012-2510515 2012-06-19 00:00:00
# 16 ES-2013-4380115 2013-02-15 00:00:00
# 17 ES-2013-4380115 2013-02-15 00:00:00
# 18 ES-2013-4380115 2013-02-15 00:00:00
# 19 ES-2014-2573330 2014-11-03 00:00:00
# 20 ES-2014-2573330 2014-11-03 00:00:00
# 21 ES-2014-1872792 2014-08-14 00:00:00
# 22 ES-2014-3412387 2014-06-18 00:00:00
# 23 IT-2014-3245851 2014-05-02 00:00:00
# ...

# %%
Retourssheets['D1']='new_coll'

# %%
for i in range(2,285):
    Retourssheets['D'+str(i)]=str(Retourssheets['A'+str(i)].value)+ '-NO-tag'

# %%
wb.save('Exemple_Hypermarché.xlsx')
